# %%
import pandas as pd
import numpy as np
import warnings

# to make a clean output
np.seterr(over='ignore', divide='ignore', invalid='ignore')
warnings.filterwarnings("ignore", category=RuntimeWarning)

df = pd.read_csv("cleaned_data.csv")
df.shape
# Out:
# (5297, 148)

# %%
target = "hospital_expire_flag"

# Columns we don't want to use as features
id_cols = [
    "subject_id", "hadm_id", "stay_id",
    "Group_Name", "Term", "DOID", "ICD10Code"
]

time_cols = [
    "dod", "admittime", "dischtime",
    "icu_intime", "icu_outtime",
    "admittime_1", "dischtime_1", "deathtime", "dod_1"
]

leak_cols = ["los_hospital", "los_icu"]

drop_cols = id_cols + time_cols + leak_cols + [target] + ["race"]

# define the feature matrix and respond vector
X = df.drop(columns=[c for c in drop_cols if c in df.columns])
y = df[target]
# convert the subject id to patient index
codes, uniques = pd.factorize(df['subject_id'])

# make sure all the columns of the feature matrix is numeric for regression
bool_cols = X.select_dtypes("bool").columns
X[bool_cols] = X[bool_cols].astype(int)
cat_cols = X.select_dtypes(include=["object", "category"]).columns.tolist()
X_encoded = pd.get_dummies(X, columns=cat_cols, drop_first=True)
feature_names = X_encoded.columns.to_list()
X = X_encoded.to_numpy(dtype=float)
y = y.to_numpy(dtype=float)
ids = codes.astype(int)

# %%
uniques
# Out:
# Index([13263248, 19226487, 19091570, 16731711, 15792737, 19713923, 15107154,
#        12796016, 15994443, 18722018,
#        ...
#        13974066, 12490029, 10035631, 13109270, 11429121, 13759534, 17431114,
#        14856789, 13675167, 19650793],
#       dtype='int64', length=1965)

# %%
from polyagamma import random_polyagamma
from numpy.random import default_rng

def pg_update_beta_b(beta_curr, b_curr, z_curr, X, Z_mat, y,
                     sigma0=100.0, sigma2_b=1.0, rng=None):
    """
    A single step for Polya Gamma Data Augmentation step
    beta_curr: the entire beta vector sampled from last step
    b_curr: the random effect for each id sampled from last step
    z_curr: the binary indicator sampled from the last step
    X: the covariate matrix
    Z_mat: ID matrix, (i, j)-entry means whether i-th patient has ID j
    y: the binary outcome
    sigma0: prior parameter for beta_curr
    sigma2_b: prior parameter for z_curr
    """

    if rng is None:
        rng = default_rng()

    # compute eta and clip eta to avoid overflow
    eta = X @ (beta_curr * z_curr) + Z_mat @ b_curr
    eta = np.clip(eta, -30.0, 30.0)
    # sample the latent variable from PG
    omega = random_polyagamma(1.0, np.asarray(eta, dtype=float))

    # stack the covariate matrix and the dummy variable, the id matrix
    X_z = X * z_curr
    X_s = np.hstack([X_z, Z_mat])
    
    p = X.shape[1]
    n_id = Z_mat.shape[1]

    # combine the two prior parameters by vectors to form the precision matrix
    tau_beta = np.full(p, 1.0 / sigma0**2)
    tau_b = np.full(n_id, 1.0 / sigma2_b)
    prec_mat = np.diag(np.concatenate([tau_beta, tau_b]))

    # the precision matrix for sampling
    Omega = np.diag(omega)
    prec_post = X_s.T @ Omega @ X_s + prec_mat
    # increase ridge if Cholesky could not be performed, avoiding issues during inverse
    I_q = np.eye(prec_post.shape[0])
    eps = 1e-6
    for _ in range(6):
        try:
            prec_post_reg = prec_post + eps * I_q
            R = np.linalg.cholesky(prec_post_reg) 
            break
        except np.linalg.LinAlgError:
            eps *= 10.0

    # mean for sampling
    kappa = y - 0.5
    m_om = np.linalg.solve(prec_post_reg, X_s.T @ kappa)

    # sample from MNV via Cholesky and shift
    z = rng.normal(size=prec_post_reg.shape[0])
    u = np.linalg.solve(R.T, z)
    theta_new = m_om + u

    beta_new = theta_new[:p]
    b_new = theta_new[p:]

    return beta_new, b_new

# %%
from scipy.special import expit

def update_sigma2_b(b_curr, a0=0.001, b0=0.001, rng=None):
    """
    Inverse Gamma conjugate posterior with a normal likelihood
    """
    if rng is None:
        rng = np.random.default_rng()
    n_id = b_curr.shape[0]
    a_post = a0 + n_id / 2.0
    b_post = b0 + 0.5 * np.sum(b_curr**2)
    gamma_sample = rng.gamma(shape=a_post, scale=1.0 / b_post)
    return 1.0 / gamma_sample

def loglik_hier(beta, z, b, X, y, ids):
    """
    A simplier version of calculating logistic log-likelihood
    """
    eta = X @ (beta * z) + b[ids]
    return np.sum(y * eta - np.log1p(np.exp(eta)))

def flip_z_hier(z_curr, beta_curr, b_curr, X, y, ids, rng=None):
    """
    A single update for z
    """
    if rng is None:
        rng = np.random.default_rng()

    p = len(z_curr)
    z = z_curr.copy()

    for j in rng.permutation(p):
        z0 = z.copy()
        z1 = z.copy()
        # propose the flip
        z0[j] = 0.0
        z1[j] = 1.0
        # compute the corresponding likelihood
        ll0 = loglik_hier(beta_curr, z0, b_curr, X, y, ids)
        ll1 = loglik_hier(beta_curr, z1, b_curr, X, y, ids)
        # compute the full conditional probability
        log_odds = ll1 - ll0
        p1 = expit(log_odds)

        z[j] = rng.binomial(1, p1)

    return z

# %%
def run_mcmc_pg_hier(X, y, ids,
                     sigma0=100.0,
                     n_iter=5000,
                     burn_in=1000,
                     a0=0.001, b0=0.001,
                     seed=111):
    """
    X: (n, p) numpy array
    y: (n,) numpy array, 0/1
    ids: (n,) numpy array of subject indices, should be converted 0,...,n_id-1
    """
    rng = default_rng(seed)

    n, p = X.shape
    n_id = len(np.unique(ids))

    # initialize parameters
    beta_curr = np.zeros(p)
    z_curr = np.ones(p)
    sigma2_b = 1.0
    b_curr = rng.normal(loc=0.0, scale=np.sqrt(sigma2_b), size=n_id)

    # matrices to store the samples
    B_save = np.zeros((n_iter, p)) # beta parameters
    Z_save = np.zeros((n_iter, p)) # feature selection indicator
    sigma2_b_save = np.zeros(n_iter)

    # construct the id dummy variable
    Z_mat = np.zeros((n, n_id), dtype=float)
    Z_mat[np.arange(n), ids] = 1.0

    for it in range(n_iter):
        # update coefs by PG method
        beta_curr, b_curr = pg_update_beta_b(
            beta_curr, b_curr, z_curr, X, Z_mat, y,
            sigma0=sigma0, sigma2_b=sigma2_b, rng=rng
        )

        # update sigma_b^2
        sigma2_b = update_sigma2_b(b_curr, a0=a0, b0=b0, rng=rng)

        # update z
        z_curr = flip_z_hier(z_curr, beta_curr, b_curr, X, y, ids, rng=rng)

        # save
        B_save[it, :] = beta_curr
        Z_save[it, :] = z_curr
        sigma2_b_save[it] = sigma2_b

        if (it + 1) % 1000 == 0:
            print(f"iter = {it+1} / {n_iter}")

    # discard the burnin period
    keep = np.arange(burn_in, n_iter)

    return {
        "B": B_save[keep, :],
        "Z": Z_save[keep, :],
        "sigma2_b": sigma2_b_save[keep]
    }

# %%
from sklearn.preprocessing import StandardScaler

subjects = df["subject_id"].unique()
rng = np.random.default_rng(638)
# assign the subject ids to random order and pick 80%
rng.shuffle(subjects)
n_train_subj = int(0.8 * len(subjects))
# split the train and test ids
train_subj = subjects[:n_train_subj]
test_subj = subjects[n_train_subj:]

# extract the corresponding patients' records
train_mask = df["subject_id"].isin(train_subj).values
test_mask = ~train_mask
# split the train and test data
X_train = X[train_mask, :]
y_train = y[train_mask]
X_test = X[test_mask, :]
y_test = y[test_mask]

# extract the train and test ids in order
codes_train, uniq_train = pd.factorize(df.loc[train_mask, "subject_id"])
codes_test, uniq_test = pd.factorize(df.loc[test_mask, "subject_id"])
# turn them to id index
ids_train = codes_train.astype(int)
ids_test = codes_test.astype(int)

# standardize
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# run model with uninformative prior for 4 different chains
n_chains = 4
seeds = [111, 199, 204, 421] 

B_list = []
Z_list = []
sigma2_list = []

for sd in seeds:
    sample_dict = run_mcmc_pg_hier(
        X_train_scaled, y_train, ids_train,
        sigma0=10,
        n_iter=8000,
        burn_in=2000,
        a0=0.001, b0=0.001,
        seed=sd
    )
    B_list.append(sample_dict["B"])
    Z_list.append(sample_dict["Z"])
    sigma2_list.append(sample_dict["sigma2_b"])

# stack the results to the form of chain
B_samples = np.stack(B_list, axis=0)
Z_samples = np.stack(Z_list, axis=0) 
sigma2_samples = np.stack(sigma2_list, axis=0)
# Out:
# iter = 1000 / 8000
# iter = 2000 / 8000
# iter = 3000 / 8000
# iter = 4000 / 8000
# iter = 5000 / 8000
# iter = 6000 / 8000
# iter = 7000 / 8000
# iter = 8000 / 8000
# iter = 1000 / 8000
# iter = 2000 / 8000
# iter = 3000 / 8000
# iter = 4000 / 8000
# iter = 5000 / 8000
# iter = 6000 / 8000
# iter = 7000 / 8000
# iter = 8000 / 8000
# iter = 1000 / 8000
# iter = 2000 / 8000
# iter = 3000 / 8000
# iter = 4000 / 8000
# iter = 5000 / 8000
# iter = 6000 / 8000
# iter = 7000 / 8000
# iter = 8000 / 8000
# iter = 1000 / 8000
# iter = 2000 / 8000
# iter = 3000 / 8000
# iter = 4000 / 8000
# iter = 5000 / 8000
# iter = 6000 / 8000
# iter = 7000 / 8000
# iter = 8000 / 8000

# %%
# compute the effective sample size of beta
import arviz as az
import xarray as xr
import matplotlib.pyplot as plt

C, S, p = B_samples.shape

beta_da = xr.DataArray(
    B_samples,
    dims=("chain", "draw", "beta")
)

# calculate ess and extract
ess_beta_da = az.ess(beta_da)
ess_beta = ess_beta_da["x"].values
print("median ESS of beta samples:", np.median(ess_beta))

plt.hist(ess_beta, bins=30)
plt.xlabel("ESS")
plt.ylabel("count")
plt.title("ESS distribution for all beta")
plt.show()

# R-hat to analyse the var / convergence
rhat_beta_da = az.rhat(beta_da)
rhat_beta = rhat_beta_da["x"].values
print("max R-hat of beta samples:", np.max(rhat_beta))
# Out:
# median ESS of beta samples: 23535.91041142825
# max R-hat of beta samples: 1.1239379700769354

# %% [markdown]
# We could see from the histogram that for a very large proportion of features, the effective sample size are close to the total number of post-burnin iterations, suggesting well mixing and independent posterior samples.

# %%
# average over chains to compute the posterior inclusion probability
pip_all = Z_samples.mean(axis=(0, 1))

# extract the important features suggested by the model
feature_idx = np.where(pip_all > 0.5)[0]
feature_names_np = np.array(feature_names)

pip_table = pd.DataFrame({
    "index": feature_idx,
    "feature": feature_names_np[feature_idx],
    "PIP": pip_all[feature_idx]
})

pip_table = pip_table.sort_values("PIP", ascending=False).reset_index(drop=True)

pip_table.style.hide(axis="index")
# Out:
# <style type="text/css">
# </style>
# <table id="T_69b5d">
#   <thead>
#     <tr>
#       <th id="T_69b5d_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_69b5d_level0_col1" class="col_heading level0 col1" >feature</th>
#       <th id="T_69b5d_level0_col2" class="col_heading level0 col2" >PIP</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_69b5d_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_69b5d_row0_col1" class="data row0 col1" >first_hosp_stay</td>
#       <td id="T_69b5d_row0_col2" class="data row0 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_69b5d_row1_col0" class="data row1 col0" >119</td>
#       <td id="T_69b5d_row1_col1" class="data row1 col1" >urineoutput</td>
#       <td id="T_69b5d_row1_col2" class="data row1 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <td id="T_69b5d_row2_col0" class="data row2 col0" >70</td>
#       <td id="T_69b5d_row2_col1" class="data row2 col1" >heart_rate_max</td>
#       <td id="T_69b5d_row2_col2" class="data row2 col2" >0.995833</td>
#     </tr>
#     <tr>
#       <td id="T_69b5d_row3_col0" class="data row3 col0" >112</td>
#       <td id="T_69b5d_row3_col1" class="data row3 col1" >temperature_max_1</td>
#       <td id="T_69b5d_row3_col2" class="data row3 col2" >0.867583</td>
#     </tr>
#     <tr>
#       <td id="T_69b5d_row4_col0" class="data row4 col0" >111</td>
#       <td id="T_69b5d_row4_col1" class="data row4 col1" >temperature_min_1</td>
#       <td id="T_69b5d_row4_col2" class="data row4 col2" >0.866875</td>
#     </tr>
#     <tr>
#       <td id="T_69b5d_row5_col0" class="data row5 col0" >86</td>
#       <td id="T_69b5d_row5_col1" class="data row5 col1" >temperature_mean</td>
#       <td id="T_69b5d_row5_col2" class="data row5 col2" >0.725417</td>
#     </tr>
#     <tr>
#       <td id="T_69b5d_row6_col0" class="data row6 col0" >62</td>
#       <td id="T_69b5d_row6_col1" class="data row6 col1" >bilirubin_total_max</td>
#       <td id="T_69b5d_row6_col2" class="data row6 col2" >0.691125</td>
#     </tr>
#     <tr>
#       <td id="T_69b5d_row7_col0" class="data row7 col0" >16</td>
#       <td id="T_69b5d_row7_col1" class="data row7 col1" >albumin_max</td>
#       <td id="T_69b5d_row7_col2" class="data row7 col2" >0.676708</td>
#     </tr>
#     <tr>
#       <td id="T_69b5d_row8_col0" class="data row8 col0" >65</td>
#       <td id="T_69b5d_row8_col1" class="data row8 col1" >ck_mb_min</td>
#       <td id="T_69b5d_row8_col2" class="data row8 col2" >0.670250</td>
#     </tr>
#     <tr>
#       <td id="T_69b5d_row9_col0" class="data row9 col0" >135</td>
#       <td id="T_69b5d_row9_col1" class="data row9 col1" >admission_location_INTERNAL TRANSFER TO OR FROM PSYCH</td>
#       <td id="T_69b5d_row9_col2" class="data row9 col2" >0.592500</td>
#     </tr>
#     <tr>
#       <td id="T_69b5d_row10_col0" class="data row10 col0" >5</td>
#       <td id="T_69b5d_row10_col1" class="data row10 col1" >anchor_age</td>
#       <td id="T_69b5d_row10_col2" class="data row10 col2" >0.549417</td>
#     </tr>
#     <tr>
#       <td id="T_69b5d_row11_col0" class="data row11 col0" >3</td>
#       <td id="T_69b5d_row11_col1" class="data row11 col1" >icustay_seq</td>
#       <td id="T_69b5d_row11_col2" class="data row11 col2" >0.518792</td>
#     </tr>
#     <tr>
#       <td id="T_69b5d_row12_col0" class="data row12 col0" >63</td>
#       <td id="T_69b5d_row12_col1" class="data row12 col1" >ck_cpk_min</td>
#       <td id="T_69b5d_row12_col2" class="data row12 col2" >0.504625</td>
#     </tr>
#   </tbody>
# </table>

# %%
pip_table.to_csv("pip_table.csv", index=False)

# %% [markdown]
# This enjoys a large overlap with our XGBoost result.

# %%
# posterior predictive check
from scipy.special import expit
from sklearn.metrics import roc_auc_score

C, S, p = B_samples.shape
n_test = X_test_scaled.shape[0]
n_subj_test = len(uniq_test)

# flatten over all chains
B_flat = B_samples.reshape(-1, p)
Z_flat = Z_samples.reshape(-1, p)
sigma2_flat = sigma2_samples.reshape(-1)
S_total = B_flat.shape[0] # total number of samples

# to store the prediction for test
p_test_s = np.zeros((S_total, n_test))
rng = np.random.default_rng(638)

# predict by each sample
for s in range(S_total):
    # extract samples
    beta_s = B_flat[s, :]
    z_s = Z_flat[s, :]
    sigma2b_s = sigma2_flat[s]

    # assign a subject-specific randomness for each subject
    b_new_subj = rng.normal(loc=0.0, scale=np.sqrt(sigma2b_s), size=n_subj_test)
    
    # predict the bernoulli probability
    eta_s = X_test_scaled @ (beta_s * z_s) + b_new_subj[ids_test]
    p_test_s[s, :] = expit(eta_s)

# mean among the predictions
p_test_hat = p_test_s.mean(axis=0)

# compute the auc for the prediction
auc_pg = roc_auc_score(y_test, p_test_hat)

print("AUC by Polya-Gamma hierarchical model:", auc_pg)
# Out:
# AUC by Polya-Gamma hierarchical model: 0.7150963927156261
